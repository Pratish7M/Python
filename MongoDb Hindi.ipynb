# %%
#https://www.mongodb.com/

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://pwskills:pwskills@cluster0.ln0bt5m.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (4.4.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pymongo) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
db
# Out:
# Database(MongoClient(host=['ac-2blvghl-shard-00-00.ln0bt5m.mongodb.net:27017', 'ac-2blvghl-shard-00-01.ln0bt5m.mongodb.net:27017', 'ac-2blvghl-shard-00-02.ln0bt5m.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-bpwwyw-shard-0', tls=True), 'test')

# %%
client = pymongo.MongoClient("mongodb+srv://pwskills:pwskills@cluster0.ln0bt5m.mongodb.net/?retryWrites=true&w=majority")

# %%
db = client['pwskills']

# %%
data = {"name" : "sudh" ,
        "class" :"data science masters " ,
        "time" : "flexi"}

# %%
coll_pwskills = db["my_record"]

# %%
coll_pwskills.insert_one(data)

# %%
data1 = {"mail_id" : "sudh@gmail.com",
         "phone_number " : 2323424324,
         "addr" : "bangalore"
}

# %%
coll_pwskills.insert_one(data1)

# %%
 data2 = [
  { "name": "Amy", "address": "Apple st 652" },
  { "name": "Hannah", "address": "Mountain 21" },
  { "name": "Michael", "address": "Valley 345" },
  { "name": "Sandy", "address": "Ocean blvd 2" },
  { "name": "Betty", "address": "Green Grass 1" },
  { "name": "Richard", "address": "Sky st 331" },
  { "name": "Susan", "address": "One way 98" },
  { "name": "Vicky", "address": "Yellow Garden 2" },
  { "name": "Ben", "address": "Park Lane 38" },
  { "name": "William", "address": "Central st 954" },
  { "name": "Chuck", "address": "Main Road 989" },
  { "name": "Viola", "address": "Sideway 1633" }
]

# %%
coll_pwskills.insert_many(data2)

# %%
data3 = {
 "name": "notebook",
 "qty": 50,
 "rating": [ { "score": 8 }, { "score": 9 } ],
 "size": { "height": 11, "width": 8.5, "unit": "in" },
 "status": "A",
 "tags": [ "college-ruled", "perforated"]
}

# %%
coll_pwskills.insert_one(data3)

# %%
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},

    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},

    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

# %%
coll_pwskills.insert_many(list_of_records)

# %%
coll_pwskills.find_one()
# Out:
# {'_id': ObjectId('65360e0244da6ca9c0c49cf9'),
#  'name': 'sudh',
#  'class': 'data science masters ',
#  'time': 'flexi'}

# %%
for i in coll_pwskills.find():
    print(i)
# Out:
# {'_id': ObjectId('65360e0244da6ca9c0c49cf9'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65360e1c44da6ca9c0c49cfa'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('653a76cb6079ff7ab7871dbb'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('653a76e26079ff7ab7871dbc'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('653cef1b7f3d83e3c946670c'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('654b360e379b4319435b5a41'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('654b3611379b4319435b5a42'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('654b3613379b4319435b5a4c'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('654b3613379b4319435b5a44'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('654b3613379b4319435b5a48'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('654b3613379b4319435b5a46'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('654b3613379b4319435b5a47'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('654b3613379b4319435b5a4d'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('654b3613379b4319435b5a49'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('654b3613379b4319435b5a4a'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('654b3613379b4319435b5a45'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('654b3613379b4319435b5a4e'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('654b3613379b4319435b5a4b'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('654b3613379b4319435b5a43'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('654b36c4379b4319435b5a4f'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('654b3710379b4319435b5a52'), 'companyName': 'pwskills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('654b3710379b4319435b5a51'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('654b3710379b4319435b5a50'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('654b3753379b4319435b5a53'), 'name': 'Rishav', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': '4', 'companyName': 'pwskills', 'Faculty': 'ABC'}
# {'_id': '3', 'companyName': 'pwskills', 'Faculty': 'XYZ'}
# {'_id': '5', 'companyName': 'pwskills', 'Faculty': 'PQR'}
# {'_id': ObjectId('657bea8d6cf4a5c75bab1570'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657c641fa772717627fa72bc'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657c651ca772717627fa72bd'), 'mail_id': 'sudh@gmail.com', 'phone_number': 2356788999, 'add': 'mumbai'}
# {'_id': ObjectId('657c6d78a772717627fa72c1'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657c6d83a772717627fa72c2'), 'mail_id': 'sudh@gmail.com', 'phone_number': 2356788999, 'add': 'mumbai'}
# {'_id': ObjectId('657d2df7e48c47692c2d0569'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657d2e03e48c47692c2d056a'), 'mail_id': 'sudh@gmail.com', 'phone_number': 2356788999, 'add': 'mumbai'}
# {'_id': ObjectId('657d2f84e48c47692c2d056b'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['collage-ruled', 'perforated']}
# {'_id': ObjectId('657d3423e48c47692c2d056c'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('657d3423e48c47692c2d056d'), 'companyName': 'pwskills', 'product': 'Affordable AI ', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('657d3423e48c47692c2d056e'), 'companyName': 'pwskills', 'product': 'Master program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('657e885fc0b419ade6dc8b73'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657e886ac0b419ade6dc8b74'), 'mail_id': 'sudh@gmail.com', 'phone_number': 2356788999, 'add': 'mumbai'}
# {'_id': ObjectId('657e8876c0b419ade6dc8b75'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['collage-ruled', 'perforated']}
# {'_id': ObjectId('657e887fc0b419ade6dc8b76'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('657e887fc0b419ade6dc8b77'), 'companyName': 'pwskills', 'product': 'Affordable AI ', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('657e887fc0b419ade6dc8b78'), 'companyName': 'pwskills', 'product': 'Master program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('657fdb2c02d97021395aea90'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657fdb3202d97021395aea91'), 'mail_id': 'sudh@gmail.com', 'phone_number': 2356788999, 'add': 'mumbai'}
# {'_id': ObjectId('657fdb3e02d97021395aea92'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['collage-ruled', 'perforated']}
# {'_id': ObjectId('657fdb4502d97021395aea93'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('657fdb4502d97021395aea94'), 'companyName': 'pwskills', 'product': 'Affordable AI ', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('657fdb4502d97021395aea95'), 'companyName': 'pwskills', 'product': 'Master program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('65a142620089a86ec5597e80'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65a142630089a86ec5597e81'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('65a142630089a86ec5597e82'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('65a142630089a86ec5597e83'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('65a142630089a86ec5597e84'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('65a142630089a86ec5597e85'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('65a142630089a86ec5597e86'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('65a142630089a86ec5597e87'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('65a142630089a86ec5597e88'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('65a142630089a86ec5597e89'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('65a142630089a86ec5597e8a'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('65a142630089a86ec5597e8b'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('65a142630089a86ec5597e8c'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('65a142630089a86ec5597e8d'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('65a142630089a86ec5597e8e'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('65a142630089a86ec5597e8f'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('65a142630089a86ec5597e90'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('65a142630089a86ec5597e91'), 'companyName': 'pwskills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('65a146db74ba0dc9262705b3'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65a146dc74ba0dc9262705b4'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('65a146df74ba0dc9262705b5'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('65a146df74ba0dc9262705b6'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('65a146df74ba0dc9262705b7'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('65a146df74ba0dc9262705b8'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('65a146df74ba0dc9262705b9'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('65a146df74ba0dc9262705ba'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('65a146df74ba0dc9262705bb'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('65a146df74ba0dc9262705bc'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('65a146df74ba0dc9262705bd'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('65a146df74ba0dc9262705be'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('65a146df74ba0dc9262705bf'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('65a146df74ba0dc9262705c0'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('65a146e174ba0dc9262705c1'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('65a146e274ba0dc9262705c2'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('65a146e274ba0dc9262705c3'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('65a146e274ba0dc9262705c4'), 'companyName': 'pwskills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('65b37d94e5a6e95b1e2a3465'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65b37d96e5a6e95b1e2a3466'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('65b37da9e5a6e95b1e2a3467'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65d50b2a3cb72b0488ab8513'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65d50b323cb72b0488ab8514'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('65d50b323cb72b0488ab8515'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('65d50b323cb72b0488ab8516'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('65d50b323cb72b0488ab8517'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('65d50b323cb72b0488ab8518'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('65d50b323cb72b0488ab8519'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('65d50b323cb72b0488ab851a'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('65d50b323cb72b0488ab851b'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('65d50b323cb72b0488ab851c'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('65d50b323cb72b0488ab851d'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('65d50b323cb72b0488ab851e'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('65d50b323cb72b0488ab851f'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('65d50b323cb72b0488ab8520'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('65d50b363cb72b0488ab8521'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('65d50b373cb72b0488ab8522'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('65d50b373cb72b0488ab8523'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('65d50b373cb72b0488ab8524'), 'companyName': 'pwskills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('65dfddcfdaa6f880ac17d319'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65e1edcb40828aa4f70fda76'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65e1f0404a50ed358d049bf6'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65e1f0454a50ed358d049bf7'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('65e8b2f6921464ea3df4db05'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65e8b308921464ea3df4db06'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('65e8b310921464ea3df4db10'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('65e8b310921464ea3df4db0d'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('65e8b310921464ea3df4db0a'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('65e8b310921464ea3df4db0e'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('65e8b310921464ea3df4db08'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('65e8b310921464ea3df4db0b'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('65e8b310921464ea3df4db12'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('65e8b310921464ea3df4db0c'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('65e8b310921464ea3df4db11'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('65e8b310921464ea3df4db07'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('65e8b310921464ea3df4db09'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('65e8b310921464ea3df4db0f'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('65e8b316921464ea3df4db13'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('65e8b31d921464ea3df4db15'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('65e8b31d921464ea3df4db14'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('65e8b31d921464ea3df4db16'), 'companyName': 'pwskills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('660a762466ef381e8e9bba7b'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('660a762566ef381e8e9bba7c'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('660a762566ef381e8e9bba83'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('660a762566ef381e8e9bba81'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('660a762566ef381e8e9bba84'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('660a762566ef381e8e9bba7e'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('660a762566ef381e8e9bba7d'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('660a762566ef381e8e9bba82'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('660a762566ef381e8e9bba85'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('660a762566ef381e8e9bba88'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('660a762566ef381e8e9bba86'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('660a762566ef381e8e9bba87'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('660a762566ef381e8e9bba7f'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('660a762566ef381e8e9bba80'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('660a762566ef381e8e9bba89'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('660a762566ef381e8e9bba8a'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('660a762566ef381e8e9bba8c'), 'companyName': 'pwskills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('660a762566ef381e8e9bba8b'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('6630bce8172153ff60ab9ea9'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('6661ddcc1a53ead29c401da7'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('666db13b939c29a5e9b22914'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('666db140939c29a5e9b22915'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('666db149939c29a5e9b22916'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('666db149939c29a5e9b22917'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('666db149939c29a5e9b22918'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('666db149939c29a5e9b22919'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('666db149939c29a5e9b2291a'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('666db149939c29a5e9b2291b'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('666db149939c29a5e9b2291c'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('666db149939c29a5e9b2291d'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('666db149939c29a5e9b2291e'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('666db149939c29a5e9b2291f'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('666db149939c29a5e9b22920'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('666db149939c29a5e9b22921'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('666db14a939c29a5e9b22922'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('666db14c939c29a5e9b22923'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('666db14c939c29a5e9b22924'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('666db14c939c29a5e9b22925'), 'companyName': 'pwskills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': ObjectId('667ad8811df02e0051227f6e'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('667ad8861df02e0051227f6f'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('66923251a867427289806fcf'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('66923252a867427289806fd0'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('66923252a867427289806fd1'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('66923252a867427289806fd2'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('66923252a867427289806fd3'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('66923252a867427289806fd4'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('66923252a867427289806fd5'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('66923252a867427289806fd6'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('66923252a867427289806fd7'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('66923252a867427289806fd8'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('66923252a867427289806fd9'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('66923252a867427289806fda'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('66923252a867427289806fdb'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('66923252a867427289806fdc'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('66923252a867427289806fdd'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('66923252a867427289806fde'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('66923252a867427289806fdf'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('66923252a867427289806fe0'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
for i in coll_pwskills.find({'name': 'sudh'}):
    print(i)
# Out:
# {'_id': ObjectId('65360e0244da6ca9c0c49cf9'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('653a76cb6079ff7ab7871dbb'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('653cef1b7f3d83e3c946670c'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('654b360e379b4319435b5a41'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('657bea8d6cf4a5c75bab1570'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657c641fa772717627fa72bc'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657c6d78a772717627fa72c1'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657d2df7e48c47692c2d0569'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657e885fc0b419ade6dc8b73'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('657fdb2c02d97021395aea90'), 'name': 'sudh', 'class': 'data science masters', 'time': 'flexi'}
# {'_id': ObjectId('65a142620089a86ec5597e80'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65a146db74ba0dc9262705b3'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65b37d94e5a6e95b1e2a3465'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65b37da9e5a6e95b1e2a3467'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65d50b2a3cb72b0488ab8513'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65dfddcfdaa6f880ac17d319'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65e1edcb40828aa4f70fda76'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65e1f0404a50ed358d049bf6'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('65e8b2f6921464ea3df4db05'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('660a762466ef381e8e9bba7b'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('6630bce8172153ff60ab9ea9'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('6661ddcc1a53ead29c401da7'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('666db13b939c29a5e9b22914'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('667ad8811df02e0051227f6e'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('66923251a867427289806fcf'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}

# %%
for i in coll_pwskills.find({'companyName': 'iNeuron'}):
    print(i)
# Out:
# {'_id': ObjectId('66923252a867427289806fde'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('66923252a867427289806fdf'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('66923252a867427289806fe0'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}

# %%
random_data = [
    {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'XYZ'},
    {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'},
    {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'},
]

# %%
coll_pwskills.insert_many(random_data)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 coll_pwskills.insert_many(random_data)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\_csot.py:106, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     104         with _TimeoutContext(timeout):
#     105             return func(self, *args, **kwargs)
# --> 106 return func(self, *args, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\collection.py:725, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     723 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     724 blk.ops = list(gen())
# --> 725 blk.execute(write_concern, session=session)
#     726 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\bulk.py:514, in _Bulk.execute(self, write_concern, session)
#     512         return None
#     513 else:
# --> 514     return self.execute_command(generator, write_concern, session)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\bulk.py:394, in _Bulk.execute_command(self, generator, write_concern, session)
#     391     client._retry_with_session(self.is_retryable, retryable_bulk, s, self)
#     393 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 394     _raise_bulk_write_error(full_result)
#     395 return full_result
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\bulk.py:136, in _raise_bulk_write_error(full_result)
#     134 if full_result["writeErrors"]:
#     135     full_result["writeErrors"].sort(key=lambda error: error["index"])
# --> 136 raise BulkWriteError(full_result)
#
# BulkWriteError: batch op errors occurred, full error: {'writeErrors': [{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: pwskills.my_record index: _id_ dup key: { _id: "3" }', 'keyPattern': {'_id': 1}, 'keyValue': {'_id': '3'}, 'op': {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'XYZ'}}], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}

# %%
for i in  coll_pwskills.find():
    print(i)
# Out:
# {'_id': ObjectId('63eef93f07ba7bd48aa09a98'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('63eef9ea07ba7bd48aa09a99'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9a'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9b'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9c'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9d'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9e'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9f'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa0'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa1'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa2'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa3'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa4'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa5'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('63eefb4f07ba7bd48aa09aa6'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('63eefbcd07ba7bd48aa09aa7'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('63eefbcd07ba7bd48aa09aa8'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('63eefbcd07ba7bd48aa09aa9'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'XYZ'}
# {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'}

# %%
for i in coll_pwskills.find({"_id" :{"$gte" : '4'}}):
    print(i)
# Out:
# {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'}

# %%
coll_pwskills.update_many({'companyName': 'iNeuron'} , {"$set" : {'companyName': 'pwskills'}})

# %%
for i in  coll_pwskills.find():
    print(i)
# Out:
# {'_id': ObjectId('63eef93f07ba7bd48aa09a98'), 'name': 'sudh', 'class': 'data science masters ', 'time': 'flexi'}
# {'_id': ObjectId('63eef9ea07ba7bd48aa09a99'), 'mail_id': 'sudh@gmail.com', 'phone_number ': 2323424324, 'addr': 'bangalore'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9a'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9b'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9c'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9d'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9e'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09a9f'), 'name': 'Richard', 'address': 'Sky st 331'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa0'), 'name': 'Susan', 'address': 'One way 98'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa1'), 'name': 'Vicky', 'address': 'Yellow Garden 2'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa2'), 'name': 'Ben', 'address': 'Park Lane 38'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa3'), 'name': 'William', 'address': 'Central st 954'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa4'), 'name': 'Chuck', 'address': 'Main Road 989'}
# {'_id': ObjectId('63eefaf107ba7bd48aa09aa5'), 'name': 'Viola', 'address': 'Sideway 1633'}
# {'_id': ObjectId('63eefb4f07ba7bd48aa09aa6'), 'name': 'notebook', 'qty': 50, 'rating': [{'score': 8}, {'score': 9}], 'size': {'height': 11, 'width': 8.5, 'unit': 'in'}, 'status': 'A', 'tags': ['college-ruled', 'perforated']}
# {'_id': ObjectId('63eefbcd07ba7bd48aa09aa7'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('63eefbcd07ba7bd48aa09aa8'), 'companyName': 'pwskills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('63eefbcd07ba7bd48aa09aa9'), 'companyName': 'pwskills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': '3', 'companyName': 'pwskills', 'Faculty': 'XYZ'}
# {'_id': '4', 'companyName': 'pwskills', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'pwskills', 'Faculty': 'PQR'}
